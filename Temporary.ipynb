# %% [markdown]
# <a href="https://colab.research.google.com/github/hariPrasadCoder/GoTTR/blob/main/Temporary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# source = requests.get('https://www.redweek.com/resort/P1550-marriotts-newport-coast-villas/timeshare-rentals').text

# %%
# soup = BeautifulSoup(source, 'lxml')

# %%
from google.colab import  drive
drive.mount('/drive')
df = pd.read_csv('/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott Newport Coast Villas/2021-08-04.csv')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
df.head(50)
# Out:
#     Unnamed: 0        Listing status  ...      Sleeps Listing action
# 0            0                   NaN  ...  Sleeps:8          Rented!
# 1            1   Availability varies  ...  Sleeps:8     View posting
# 2            2   Availability varies  ...  Sleeps:8     View posting
# 3            3      RedWeek Verified  ...  Sleeps:8          Rented!
# 4            4      RedWeek Verified  ...  Sleeps:8          Rented!
# 5            5      RedWeek Verified  ...  Sleeps:8          Rented!
# 6            6      RedWeek Verified  ...  Sleeps:8          Rented!
# 7            7                   NaN  ...  Sleeps:8     View posting
# 8            8      RedWeek Verified  ...  Sleeps:8          Rented!
# 9            9      RedWeek Verified  ...  Sleeps:8          Rented!
# 10          10                   NaN  ...  Sleeps:8     View posting
# 11          11                   NaN  ...  Sleeps:8     View posting
# 12          12                   NaN  ...  Sleeps:8          Rented!
# 13          13  Verified & Protected  ...  Sleeps:8       View  Book
# 14          14                   NaN  ...  Sleeps:8       View  Book
# 15          15                   NaN  ...  Sleeps:8          Rented!
# 16          16                   NaN  ...  Sleeps:8          Rented!
# 17          17                   NaN  ...  Sleeps:8          Rented!
# 18          18                   NaN  ...  Sleeps:8          Rented!
# 19          19                   NaN  ...  Sleeps:8       View  Book
# 20          20                   NaN  ...  Sleeps:8          Rented!
# 21          21                   NaN  ...  Sleeps:8          Rented!
# 22          22                   NaN  ...  Sleeps:8     View posting
# 23          23                   NaN  ...  Sleeps:8     View posting
# 24          24                   NaN  ...  Sleeps:8     View posting
# 25          25                   NaN  ...  Sleeps:8     View posting
# 26          26                   NaN  ...  Sleeps:8          Rented!
# 27          27  Verified & Protected  ...  Sleeps:8       View  Book
# 28          28      RedWeek Verified  ...  Sleeps:8          Rented!
# 29          29      RedWeek Verified  ...  Sleeps:8          Rented!
# 30          30  Verified & Protected  ...  Sleeps:8       View  Book
# 31          31      RedWeek Verified  ...  Sleeps:8          Rented!
# 32          32      RedWeek Verified  ...  Sleeps:8          Rented!
# 33          33      RedWeek Verified  ...  Sleeps:8          Rented!
# 34          34      RedWeek Verified  ...  Sleeps:8          Rented!
# 35          35                   NaN  ...  Sleeps:8     View posting
# 36          36                   NaN  ...  Sleeps:8     View posting
# 37          37                   NaN  ...  Sleeps:8          Rented!
# 38          38                   NaN  ...  Sleeps:8     View posting
# 39          39                   NaN  ...  Sleeps:8          Rented!
# 40          40  Verified & Protected  ...  Sleeps:8       View  Book
# 41          41  Verified & Protected  ...  Sleeps:8       View  Book
# 42          42      RedWeek Verified  ...  Sleeps:8          Rented!
# 43          43      RedWeek Verified  ...  Sleeps:8          Rented!
# 44          44  Verified & Protected  ...  Sleeps:8       View  Book
# 45          45      RedWeek Verified  ...  Sleeps:8          Rented!
# 46          46      RedWeek Verified  ...  Sleeps:8          Rented!
# 47          47      RedWeek Verified  ...  Sleeps:8          Rented!
# 48          48      RedWeek Verified  ...  Sleeps:8          Rented!
# 49          49  Verified & Protected  ...  Sleeps:8       View  Book
#
# [50 rows x 9 columns]

# %%
# tabs = []
# table = soup.find("table", class_='table-listing table-listing-rentals table-listing-desktop')
# for tr in table.find_all("tr")[1:200]:
#   tabs.append({
#             'Listing status': tr.find_all('td')[0].text,
#             'Dates': tr.find_all('td')[1].text,
#             'Nights': tr.find_all('td')[2].text,
#             'Price': tr.find_all('td')[3].text,
#             'Unit view': tr.find_all('td')[4].text,
#             'Beds/Baths': tr.find_all('td')[5].text,
#             'Sleeps': tr.find_all('td')[6].text,
#             'Listing action': tr.find_all('td')[7].text
#             })
# df = pd.DataFrame(tabs)
# df = df.replace('\n','', regex=True)
# df.head(50)

# %%
df['Listing action'].value_counts()
# Out:
# Rented!         97
# View posting    54
# View  Book      48
# Name: Listing action, dtype: int64

# %%
df = df[(df['Listing action'] != 'Rented!')]
df.head()
# Out:
#     Unnamed: 0       Listing status  ...      Sleeps Listing action
# 1            1  Availability varies  ...  Sleeps:8     View posting
# 2            2  Availability varies  ...  Sleeps:8     View posting
# 7            7                  NaN  ...  Sleeps:8     View posting
# 10          10                  NaN  ...  Sleeps:8     View posting
# 11          11                  NaN  ...  Sleeps:8     View posting
#
# [5 rows x 9 columns]

# %%
df['Listing status'].value_counts()
# Out:
# Verified & Protected    38
# Availability varies      3
# RedWeek Verified         3
# Name: Listing status, dtype: int64

# %%
df['Listing status'] = df['Listing status'].replace({np.nan:'Unprotected','RedWeek Verified':'Unprotected','Availability varies':'Unprotected','Verified & Protected':'Protected'})

# %%
df = df.replace(' New!','', regex=True)

# %%
df = df[['Listing status','Dates','Price']]

# %%
df.head(50)
# Out:
#     Listing status  ...                         Price
# 1      Unprotected  ...    $1,695 ($242/night)
# 2      Unprotected  ...  $1,495 ($1,495/night)
# 7      Unprotected  ...    $1,500 ($375/night)
# 10     Unprotected  ...    $2,595 ($371/night)
# 11     Unprotected  ...    $2,850 ($407/night)
# 13       Protected  ...    $3,299 ($471/night)
# 14     Unprotected  ...    $2,400 ($343/night)
# 19     Unprotected  ...    $5,395 ($385/night)
# 22     Unprotected  ...    $2,950 ($421/night)
# 23     Unprotected  ...    $2,295 ($328/night)
# 24     Unprotected  ...    $2,495 ($356/night)
# 25     Unprotected  ...    $2,995 ($428/night)
# 27       Protected  ...    $3,500 ($500/night)
# 30       Protected  ...    $2,600 ($371/night)
# 35     Unprotected  ...    $2,650 ($379/night)
# 36     Unprotected  ...    $2,750 ($393/night)
# 38     Unprotected  ...    $3,549 ($507/night)
# 40       Protected  ...    $2,695 ($385/night)
# 41       Protected  ...    $2,600 ($371/night)
# 44       Protected  ...    $2,800 ($400/night)
# 49       Protected  ...    $2,940 ($420/night)
# 50       Protected  ...    $2,750 ($393/night)
# 52     Unprotected  ...    $2,149 ($307/night)
# 53     Unprotected  ...    $2,650 ($379/night)
# 54     Unprotected  ...    $3,200 ($457/night)
# 55     Unprotected  ...    $2,600 ($371/night)
# 56     Unprotected  ...    $3,500 ($500/night)
# 57     Unprotected  ...    $2,999 ($428/night)
# 58     Unprotected  ...    $2,800 ($400/night)
# 60       Protected  ...    $2,400 ($343/night)
# 67       Protected  ...    $2,600 ($371/night)
# 68       Protected  ...    $2,700 ($386/night)
# 69       Protected  ...    $2,650 ($379/night)
# 71       Protected  ...    $1,800 ($300/night)
# 74     Unprotected  ...    $2,200 ($314/night)
# 75     Unprotected  ...    $2,950 ($421/night)
# 76     Unprotected  ...    $2,100 ($300/night)
# 79     Unprotected  ...    $2,750 ($393/night)
# 81     Unprotected  ...    $2,800 ($400/night)
# 86     Unprotected  ...    $1,850 ($370/night)
# 87     Unprotected  ...    $1,929 ($386/night)
# 88     Unprotected  ...    $2,400 ($480/night)
# 91       Protected  ...    $2,200 ($314/night)
# 95       Protected  ...    $2,200 ($314/night)
# 96       Protected  ...    $2,000 ($286/night)
# 98       Protected  ...    $2,835 ($405/night)
# 99       Protected  ...    $2,400 ($343/night)
# 100    Unprotected  ...    $3,500 ($500/night)
# 101    Unprotected  ...    $2,500 ($357/night)
# 102    Unprotected  ...    $3,200 ($457/night)
#
# [50 rows x 3 columns]

# %%
from datetime import date
today = date.today()

from google.colab import  drive
drive.mount('/drive')
df.to_csv(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/2021-08-04_final.csv')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
