# %% [markdown]
# <a href="https://colab.research.google.com/github/hariPrasadCoder/GoTTR/blob/main/Final_Web_scraping_of_redweek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
source = requests.get('https://www.redweek.com/resort/P1550-marriotts-newport-coast-villas/timeshare-rentals').text

# %%
soup = BeautifulSoup(source, 'lxml')

# %%
tabs = []
table = soup.find("table", class_='table-listing table-listing-rentals table-listing-desktop')
for tr in table.find_all("tr")[1:200]:
  id = tr.get('data-posting-path')
  tabs.append({
            'ID':id,
            'Listing status': tr.find_all('td')[0].text,
            'Dates': tr.find_all('td')[1].text,
            'Nights': tr.find_all('td')[2].text,
            'Price': tr.find_all('td')[3].text,
            'Unit view': tr.find_all('td')[4].text,
            'Beds/Baths': tr.find_all('td')[5].text,
            'Sleeps': tr.find_all('td')[6].text,
            'Listing action': tr.find_all('td')[7].text
            })
df = pd.DataFrame(tabs)
df = df.replace('\n','', regex=True)
df.head(50)
# Out:
#                   ID        Listing status  ...      Sleeps Listing action
# 0               None                        ...  Sleeps:8          Rented!
# 1   /posting/R732022   Availability varies  ...  Sleeps:8     View posting
# 2   /posting/R771918   Availability varies  ...  Sleeps:8     View posting
# 3               None                        ...  Sleeps:8          Rented!
# 4               None                        ...  Sleeps:8          Rented!
# 5               None                        ...  Sleeps:8          Rented!
# 6               None                        ...  Sleeps:8          Rented!
# 7   /posting/R945855                        ...  Sleeps:8     View posting
# 8               None                        ...  Sleeps:8          Rented!
# 9               None                        ...  Sleeps:8          Rented!
# 10  /posting/R650079                        ...  Sleeps:8     View posting
# 11              None                        ...  Sleeps:8          Rented!
# 12  /posting/R921150      RedWeek Verified  ...  Sleeps:8     View posting
# 13  /posting/R945734                        ...  Sleeps:8     View posting
# 14              None                        ...  Sleeps:8          Rented!
# 15              None                        ...  Sleeps:8          Rented!
# 16              None                        ...  Sleeps:8          Rented!
# 17              None                        ...  Sleeps:8          Rented!
# 18  /posting/R938610                        ...  Sleeps:8     View posting
# 19              None                        ...  Sleeps:8          Rented!
# 20              None                        ...  Sleeps:8          Rented!
# 21  /posting/R818410                        ...  Sleeps:8     View posting
# 22              None                        ...  Sleeps:8          Rented!
# 23  /posting/R943709      RedWeek Verified  ...  Sleeps:8     View posting
# 24  /posting/R942827      RedWeek Verified  ...  Sleeps:8     View posting
# 25              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 26              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 27              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 28              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 29  /posting/R945861                        ...  Sleeps:8     View posting
# 30              None                        ...  Sleeps:8          Rented!
# 31              None                        ...  Sleeps:8          Rented!
# 32  /posting/R895227                        ...  Sleeps:8     View posting
# 33              None                        ...  Sleeps:8          Rented!
# 34  /posting/R939711  Verified & Protected  ...  Sleeps:8       View  Book
# 35  /posting/R937931  Verified & Protected  ...  Sleeps:8       View  Book
# 36              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 37              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 38  /posting/R945650  Verified & Protected  ...  Sleeps:8       View  Book
# 39  /posting/R944424  Verified & Protected  ...  Sleeps:8       View  Book
# 40              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 41              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 42              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 43              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 44              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 45  /posting/R934844  Verified & Protected  ...  Sleeps:8       View  Book
# 46  /posting/R934304  Verified & Protected  ...  Sleeps:8       View  Book
# 47              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 48              None      RedWeek Verified  ...  Sleeps:8          Rented!
# 49              None                        ...  Sleeps:8          Rented!
#
# [50 rows x 9 columns]

# %%
df['Listing action'].value_counts()
# Out:
# Rented!         106
# View posting     55
# View  Book       38
# Name: Listing action, dtype: int64

# %%
df = df[(df['Listing action'] != 'Rented!')]
df.head()
# Out:
#                   ID       Listing status  ...      Sleeps Listing action
# 1   /posting/R732022  Availability varies  ...  Sleeps:8     View posting
# 2   /posting/R771918  Availability varies  ...  Sleeps:8     View posting
# 7   /posting/R945855                       ...  Sleeps:8     View posting
# 10  /posting/R650079                       ...  Sleeps:8     View posting
# 12  /posting/R921150     RedWeek Verified  ...  Sleeps:8     View posting
#
# [5 rows x 9 columns]

# %%
df['Listing status'].value_counts()
# Out:
#                         52
# Verified & Protected    32
# RedWeek Verified         6
# Availability varies      3
# Name: Listing status, dtype: int64

# %%
df['Listing status'] = df['Listing status'].replace({'':'Unprotected','RedWeek Verified':'Unprotected','Availability varies':'Unprotected','Verified & Protected':'Protected'})

# %%
df = df.replace(' New!','', regex=True)

# %%
df = df[['ID','Listing status','Dates','Price']]

# %%
df.head(50)
# Out:
#                    ID  ...                       Price
# 1    /posting/R732022  ...  $1,695 ($242/night)
# 2    /posting/R771918  ...    $699 ($699/night)
# 7    /posting/R945855  ...  $2,700 ($386/night)
# 10   /posting/R650079  ...  $2,750 ($393/night)
# 12   /posting/R921150  ...  $3,299 ($471/night)
# 13   /posting/R945734  ...  $2,500 ($357/night)
# 18   /posting/R938610  ...  $5,395 ($385/night)
# 21   /posting/R818410  ...  $2,995 ($428/night)
# 23   /posting/R943709  ...  $3,500 ($500/night)
# 24   /posting/R942827  ...  $2,600 ($371/night)
# 29   /posting/R945861  ...  $2,400 ($343/night)
# 32   /posting/R895227  ...  $2,000 ($286/night)
# 34   /posting/R939711  ...  $2,695 ($385/night)
# 35   /posting/R937931  ...  $2,600 ($371/night)
# 38   /posting/R945650  ...  $3,150 ($450/night)
# 39   /posting/R944424  ...  $2,800 ($400/night)
# 45   /posting/R934844  ...  $2,940 ($420/night)
# 46   /posting/R934304  ...  $1,950 ($279/night)
# 51   /posting/R941922  ...  $2,149 ($307/night)
# 52   /posting/R939510  ...  $2,650 ($379/night)
# 53   /posting/R934379  ...  $2,100 ($300/night)
# 54   /posting/R934390  ...  $3,200 ($457/night)
# 55   /posting/R931837  ...  $3,500 ($500/night)
# 56   /posting/R835043  ...  $2,999 ($428/night)
# 57   /posting/R677511  ...  $2,800 ($400/night)
# 59   /posting/R936193  ...  $2,400 ($343/night)
# 66   /posting/R943593  ...  $2,600 ($371/night)
# 67   /posting/R943595  ...  $2,700 ($386/night)
# 68   /posting/R943594  ...  $2,650 ($379/night)
# 70   /posting/R921587  ...  $1,800 ($300/night)
# 73   /posting/R862156  ...  $1,950 ($279/night)
# 74   /posting/R632368  ...  $2,950 ($421/night)
# 78   /posting/R937779  ...  $2,750 ($393/night)
# 80   /posting/R796295  ...  $2,800 ($400/night)
# 84   /posting/R940791  ...  $1,850 ($370/night)
# 85   /posting/R932851  ...  $1,776 ($355/night)
# 87   /posting/R690312  ...  $2,400 ($480/night)
# 88   /posting/R711065  ...  $1,049 ($350/night)
# 89   /posting/R932512  ...  $1,099 ($366/night)
# 92   /posting/R938773  ...  $1,950 ($279/night)
# 96   /posting/R898791  ...  $2,000 ($286/night)
# 97   /posting/R941721  ...  $2,000 ($286/night)
# 99   /posting/R934845  ...  $2,835 ($405/night)
# 100  /posting/R921588  ...  $2,200 ($314/night)
# 101  /posting/R934381  ...  $2,500 ($357/night)
# 102  /posting/R934378  ...  $2,100 ($300/night)
# 103  /posting/R931842  ...  $3,200 ($457/night)
# 104  /posting/R688936  ...  $2,999 ($428/night)
# 106  /posting/R937938  ...  $2,099 ($300/night)
# 109  /posting/R941723  ...  $2,100 ($300/night)
#
# [50 rows x 4 columns]

# %%
df['ID'] = df['ID'].str.strip()
df['Listing status'] = df['Listing status'].str.strip()
df['Dates'] = df['Dates'].str.strip()
df['Price'] = df['Price'].str.strip()

# %%
from datetime import date
today = date.today()

from google.colab import  drive
drive.mount('/drive')
df.to_csv(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/{today}_final.csv',index=False)
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
from datetime import datetime, timedelta
yesterday = datetime.strftime(datetime.now() - timedelta(1), '%Y-%m-%d')
yesterday
# Out:
# '2021-08-07'

# %%
import csv
f1 = open(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/{today}_final.csv','r')
f2 = open(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/{yesterday}_final.csv','r')
f3 = open(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/interpretations.csv','w')

c1 = csv.reader(f1)
c2 = csv.reader(f2)
c3 = csv.writer(f3)

# %%
yesterday_list = list(c2)

for today_row in c1:
  row = 1
  found = False
  for yesterday_row in yesterday_list:
    results_row = today_row
    if today_row[0] == yesterday_row[0] and today_row[3] == yesterday_row[3]:
      results_row.append('Unchanged')
      found = True
      break
    elif today_row[0] == yesterday_row[0] and today_row[3] != yesterday_row[3]:
      results_row.append('Price change')
      found = True
      break
    row += 1
  if not found:
    results_row.append('New Listing')
  c3.writerow(results_row)


f1.close()
f2.close()
f3.close()

# %%
f1 = open(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/{today}_final.csv','r')
f2 = open(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/{yesterday}_final.csv','r')
f3 = open(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/interpretations.csv','a')

c1 = csv.reader(f1)
c2 = csv.reader(f2)
c3 = csv.writer(f3)

today_list = list(c1)

for yesterday_row in c2:
  row = 1
  found = False
  for today_row in today_list:
    results_row = yesterday_row
    if today_row[0] == yesterday_row[0]:
      found = True
      break
    row += 1
  if not found:
    results_row.append('Rented')
    c3.writerow(results_row)

f1.close()
f2.close()
f3.close()

# %%
df = pd.read_csv('/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/interpretations.csv')

# %%
df
# Out:
#                   ID Listing status  ...                Price  Unchanged
# 0   /posting/R732022    Unprotected  ...  $1,695 ($242/night)  Unchanged
# 1   /posting/R771918    Unprotected  ...    $699 ($699/night)  Unchanged
# 2   /posting/R945855    Unprotected  ...  $2,700 ($386/night)  Unchanged
# 3   /posting/R650079    Unprotected  ...  $2,750 ($393/night)  Unchanged
# 4   /posting/R921150    Unprotected  ...  $3,299 ($471/night)  Unchanged
# ..               ...            ...  ...                  ...        ...
# 88  /posting/R944881      Protected  ...  $2,000 ($286/night)  Unchanged
# 89  /posting/R939774    Unprotected  ...  $1,950 ($279/night)  Unchanged
# 90  /posting/R929284    Unprotected  ...  $2,000 ($286/night)  Unchanged
# 91  /posting/R941623    Unprotected  ...  $1,950 ($279/night)  Unchanged
# 92  /posting/R939373    Unprotected  ...  $1,950 ($279/night)  Unchanged
#
# [93 rows x 5 columns]

# %%
df = df.sort_values(by='Dates')
df.to_csv('/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/interpretations.csv',index=False)

# %%
f3 = open(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/interpretations.csv','r')
f4 = open(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/final.csv','w')
c3 = csv.reader(f3)
c4 = csv.writer(f4)

prev = 0
lst = [1,2]
j=0
for i in c3:
  results_row = i
  if i[2] == prev:
    results_row.append(lst[j])
    prev = i[2]
  else:
    j+=1
    if j>1:
      j=0
    results_row.append(lst[j])
    prev = i[2]

  c4.writerow(results_row)

f3.close()
f4.close()

# %%
df = pd.read_csv('/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/final.csv')
df.rename(columns={'Unchanged': 'Update',
                   '2': 'S'},
          inplace=True, errors='raise')
df.to_excel(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/final_{today}.xlsx',index=False)

# %%
# !pip install xlsxwriter
import xlsxwriter

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(f'/drive/Shared drives/All Files/Timeshare platform/Python scripts/Marriott trial/final_{today}.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Get the xlsxwriter workbook and worksheet objects.
workbook  = writer.book
worksheet = writer.sheets['Sheet1']

#Color format
red_format = workbook.add_format({'bg_color': '#FFC7CE',
                               'font_color': '#9C0006'})
green_format = workbook.add_format({'bg_color': '#C6EFCE',
                               'font_color': '#006100'})
yellow_format = workbook.add_format({'bg_color': '#FFFF00'})
black_format = workbook.add_format({'bg_color': '#000000',
                               'font_color': '#000000'})
white_format = workbook.add_format({'bg_color': '#FFFFFF',
                               'font_color': '#FFFFFF'})

# Apply a conditional format to the cell range.
worksheet.conditional_format('F2:F1000', {'type':     'text',
                                       'criteria': 'containing',
                                       'value':    'New Listing',
                                       'format':   green_format})
worksheet.conditional_format('F2:F1000', {'type':     'text',
                                       'criteria': 'containing',
                                       'value':    'Price change',
                                       'format':   yellow_format})
worksheet.conditional_format('F2:F1000', {'type':     'text',
                                       'criteria': 'containing',
                                       'value':    'Rented',
                                       'format':   red_format})
worksheet.conditional_format('G2:G1000', {'type':     'cell',
                                       'criteria': '==',
                                       'value':    '1',
                                       'format':   black_format})
worksheet.conditional_format('G2:G1000', {'type':     'cell',
                                       'criteria': '==',
                                       'value':    '2',
                                       'format':   white_format})

# Set Auto column width
def get_col_widths(dataframe):
    # First we find the maximum length of the index column   
    idx_max = max([len(str(s)) for s in dataframe.index.values] + [len(str(dataframe.index.name))])
    # Then, we concatenate this to the max of the lengths of column name and its values for each column, left to right
    return [idx_max] + [max([len(str(s)) for s in dataframe[col].values] + [len(col)]) for col in dataframe.columns]

for i, width in enumerate(get_col_widths(df)):
    worksheet.set_column(i, i, width)

# Close the Pandas Excel writer and output the Excel file.
writer.save()
# Out:
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.7/dist-packages (1.4.5)
